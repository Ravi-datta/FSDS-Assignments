# %% [raw]
# 1. In the below elements which of them are values or an expression? eg:- values can be
#    integer or string and expressions will be mathematical operators.

# %% [raw]
# Ans: values     = 'hello', -87.8, 6
#      expressions= *, -, /, +

# %% [raw]
# 2. What is the difference between string and variable?

# %% [raw]
# Ans: String is a data type which represents set of characters which includes letters, numbers, symbols, spaces and line breaks      also. the numbers of string type cannot be used for calculation. we should define a string in single('') or double              quotes("").
#
#      Variable is a reference which is used to store values and use these references later in the program. the variables are of      various types like int, string, boolean, etc.

# %% [raw]
# 3. Describe three different data types.

# %% [raw]
# Ans: 1)Int: It contains positive and negative whole numbers.
#      2)float: It contains real number with decimal point.
#      3)complex: the numbers which have a real and imaginary parts. ex: 2_3j

# %% [raw]
# 4. What is an expression made up of? What do all expressions do?

# %% [raw]
# Ans: An expression is made up of variables, operators, method calls according to the syntax. All the expressions evaluates to a      single value.

# %% [raw]
# 5. This assignment statements, like spam = 10. What is the difference between an
# expression and a statement?

# %% [raw]
# Ans: Statements indicate an action or command like print statements, assignment statements. Here spam=10 is a statement and not      a expression. Expression is something that results to value and cn be calculated.

# %% [raw]
# 6. After running the following code, what does the variable bacon contain?
#    bacon = 22
#    bacon + 1

# %% [raw]
# Ans: 22

# %% [raw]
# 7. What should the values of the following two terms be?
#    'spam' + 'spamspam'
#    'spam' * 3

# %% [raw]
# Ans: 'spamspamspam'
#      'spamspamspam'

# %% [raw]
# 8. Why is eggs a valid variable name while 100 is invalid?

# %% [raw]
# Ans: According to variable naming rules in python a variable name cannot start with a number and can only contain alpha-numeric      characters and underscores.

# %% [raw]
# 9. What three functions can be used to get the integer, floating-point number, or string
#    version of a value?

# %% [raw]
# Ans: int() float() str() functions can be used to get integer, floating-point number, string
#      version of a value

# %% [raw]
# 10. Why does this expression cause an error? How can you fix it?
#     'I have eaten'+ 99 +'burritos'

# %% [raw]
# Ans: This expresiion causes error because integer cannot be joined or concatenated with string. We can fix this expression by        making the integer 99 into a string
#      'I have eaten'+ '99' +'burritos'
